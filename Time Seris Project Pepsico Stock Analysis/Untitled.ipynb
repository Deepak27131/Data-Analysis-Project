# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Pepsico_stock.csv')
df
# Out:
#             Date       Close        High         Low        Open    Volume
# 0       7/1/1985    1.253391    1.261241    1.250774    1.256007   3735000
# 1       7/2/1985    1.250774    1.261241    1.250774    1.253391   4046400
# 2       7/3/1985    1.256007    1.258624    1.256007    1.256007   2550600
# 3       7/5/1985    1.266475    1.266475    1.245542    1.245542   2237400
# 4       7/8/1985    1.245540    1.266473    1.242923    1.266473   3744000
# ...          ...         ...         ...         ...         ...       ...
# 10084  7/11/2025  135.259995  135.389999  133.809998  134.839996   7963600
# 10085  7/14/2025  135.570007  135.880005  133.860001  134.750000   8480300
# 10086  7/15/2025  133.809998  135.509995  133.750000  135.429993   8933500
# 10087  7/16/2025  135.350006  135.509995  133.750000  133.949997  10941600
# 10088  7/17/2025  145.440002  145.960007  141.639999  141.699997  26161000
#
# [10089 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10089 entries, 0 to 10088
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10089 non-null  object
#  1   Close   10089 non-null  float64
#  2   High    10089 non-null  float64
#  3   Low     10089 non-null  float64
#  4   Open    10089 non-null  float64
#  5   Volume  10089 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 473.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10089 entries, 0 to 10088
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10089 non-null  datetime64[ns]
#  1   Close   10089 non-null  float64
#  2   High    10089 non-null  float64
#  3   Low     10089 non-null  float64
#  4   Open    10089 non-null  float64
#  5   Volume  10089 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 473.1 KB

# %%
df.to_csv('stock_data.csv')

# %%
df['Open'].plot(figsize=(15,6))
# Out:
# <Axes: >

# %%
df['Open:10 days rolling'] = df['Open'].rolling(window=10,min_periods=1).mean()

# %%
df[['Open','Open:10 days rolling']].plot(figsize=(15,8))
# Out:
# <Axes: >
